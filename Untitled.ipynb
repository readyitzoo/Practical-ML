# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import make_scorer
from scipy.stats import spearmanr
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Custom Spearman correlation scorer
def spearman_corr(y_true, y_pred):
    return spearmanr(y_true, y_pred).correlation

# Custom Kendall's Tau scorer
def kendall_corr(y_true, y_pred):
    return kendalltau(y_true, y_pred).correlation

# Load data
def load_data(file_path):
    return pd.read_csv(file_path)

# Load datasets
train_file = "train.csv"
val_file = "val.csv"
test_file = "test.csv"

train_data = load_data(train_file)
val_data = load_data(val_file)
test_data = load_data(test_file)

# Extract features and targets
combined_text = pd.concat([train_data['text'], val_data['text']])
tfidf = TfidfVectorizer(max_features=750)
tfidf.fit(combined_text)

X_train = tfidf.transform(train_data['text']).toarray()
y_train = train_data['score']

X_val = tfidf.transform(val_data['text']).toarray()
y_val = val_data['score']

X_test = tfidf.transform(test_data['text']).toarray()

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Build the neural network model
model = Sequential([
    Dense(128, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=10,  # Start with 50 epochs and adjust as needed
    batch_size=16,
    verbose=1
)

# Evaluate the model
y_val_pred = model.predict(X_val).flatten()
val_correlation = spearman_corr(y_val, y_val_pred)

# Calculate the evaluation metrics
mae = mean_absolute_error(y_val, y_val_pred)
mse = mean_squared_error(y_val, y_val_pred)
spearman_corr_value = spearman_corr(y_val, y_val_pred)
kendall_corr_value = kendall_corr(y_val, y_val_pred)

# Print all evaluation metrics
print(f"Validation MAE: {mae:.4f}")
print(f"Validation MSE: {mse:.4f}")
print(f"Validation Spearman's Rank Correlation Coefficient: {spearman_corr_value:.4f}")
print(f"Validation Kendall's Tau: {kendall_corr_value:.4f}")
# Create submission file
def create_submission_file(model, test_features, test_ids, output_file):
    predictions = model.predict(test_features).flatten()
    submission = pd.DataFrame({
        'id': test_ids,
        'score': np.round(predictions, 8)
    })
    submission.to_csv(output_file, index=False)

# Generate submission file
submission_file = "submission.csv"
create_submission_file(model, X_test, test_data['id'], submission_file)
# Out:
# Epoch 1/10
# D:\Program Files\anaconda 3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 1.2332 - val_loss: 0.4891
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.4577 - val_loss: 0.4613
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.3718 - val_loss: 0.4431
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.3173 - val_loss: 0.4425
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.2811 - val_loss: 0.4436
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 0.2652 - val_loss: 0.4592
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.2414 - val_loss: 0.4515
# Epoch 8/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.2321 - val_loss: 0.4424
# Epoch 9/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.2227 - val_loss: 0.4570
# Epoch 10/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.2072 - val_loss: 0.4526
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Validation MAE: 0.5386
# Validation MSE: 0.4526
# Validation Spearman's Rank Correlation Coefficient: 0.5642
# Validation Kendall's Tau: 0.3930
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, make_scorer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.stats import spearmanr, kendalltau
from xgboost import XGBRegressor
from gensim.models import Word2Vec
from sklearn.preprocessing import normalize
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk
from math import sqrt
import matplotlib.pyplot as plt

# nltk.download("wordnet")
# nltk.download("stopwords")

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

# Custom Spearman correlation scorer
def spearman_corr(y_true, y_pred):
    return spearmanr(y_true, y_pred).correlation

# Custom Kendall's Tau scorer
def kendall_corr(y_true, y_pred):
    return kendalltau(y_true, y_pred).correlation

# Load data
def load_data(file_path):
    return pd.read_csv(file_path)

# Load datasets
train_file = "train.csv"
val_file = "val.csv"
test_file = "test.csv"

train_data = load_data(train_file)
val_data = load_data(val_file)
test_data = load_data(test_file)

# Preprocess text data for word2vec
def preprocess_text(text):
    # Remove special characters, numbers, and extra spaces
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    # Tokenize, lemmatize, and remove stopwords
    tokens = [lemmatizer.lemmatize(word.lower()) for word in text.split() if word.lower() not in stop_words]
    return tokens

# Combine text data from training, validation, and test sets into one list
train_sentences = pd.concat([train_data["text"], val_data["text"], test_data["text"]])

# Preprocess the combined sentences (e.g., tokenize, lemmatize, and clean)
combined_texts = train_sentences.apply(preprocess_text)

# Train Word2Vec model on the combined dataset
model_w2v = Word2Vec(sentences=combined_texts, vector_size=150, window=5, min_count=1, workers=5, epochs=80, seed=55)
model_w2v.save("word2vec.model")

# Create TF-IDF vectorizer
tfidf = TfidfVectorizer(max_features=700)
tfidf.fit(train_sentences.apply(lambda x: " ".join(preprocess_text(x))))

# Create word2vec embeddings for each document
def get_combined_features(text, model_w2v, tfidf_vocab):
    tfidf_scores = {word: tfidf_vocab[word] for word in text if word in tfidf_vocab}
    # Word2Vec embeddings for words in the document
    embeddings = [model_w2v.wv[word] * tfidf_scores.get(word, 0) for word in text if word in model_w2v.wv]
    if len(embeddings) == 0:
        return np.zeros(model_w2v.vector_size)
    # Return normalized combined vector
    return normalize(np.mean(embeddings, axis=0).reshape(1, -1)).flatten()

# Extract TF-IDF vocabulary
tfidf_vocab = tfidf.vocabulary_

# Apply combined features to training, validation, and test sets
X_train = np.array([get_combined_features(preprocess_text(text), model_w2v, tfidf_vocab) for text in train_data["text"]])
X_val = np.array([get_combined_features(preprocess_text(text), model_w2v, tfidf_vocab) for text in val_data["text"]])
X_test = np.array([get_combined_features(preprocess_text(text), model_w2v, tfidf_vocab) for text in test_data["text"]])

# Targets
y_train = train_data["score"].values
y_val = val_data["score"].values

# Initialize XGBRegressor with specific parameters
xgb_reg = XGBRegressor(
    objective="reg:squarederror",
    random_state=42,
    learning_rate=0.003,
    max_depth=6,
    n_estimators=300,
    subsample=0.9,
    colsample_bytree=0.6,
    lambda_=0.5,
    alpha=1
)

# Train the model without eval_metric
xgb_reg.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], verbose=True)

# Get the number of epochs (iterations)
epochs = xgb_reg.n_estimators
x_axis = range(0, epochs)

# Initialize lists to store RMSE values for train and validation sets
train_rmse = []
val_rmse = []

# Loop through each epoch to calculate RMSE
for i in range(epochs):
    # Get predictions for the current iteration
    y_train_pred = xgb_reg.predict(X_train, iteration_range=(0, i+1))
    y_val_pred = xgb_reg.predict(X_val, iteration_range=(0, i+1))

    # Calculate RMSE for train and validation
    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
    val_rmse.append(np.sqrt(mean_squared_error(y_val, y_val_pred)))

# Plotting the learning curve for RMSE
fig, ax = plt.subplots()
ax.plot(x_axis, train_rmse, label='Train RMSE')
ax.plot(x_axis, val_rmse, label='Validation RMSE')
ax.legend()
plt.xlabel('Number of Iterations')
plt.ylabel('RMSE')
plt.title('XGBoost RMSE Learning Curve')
plt.show()
# Evaluate the model on the validation data
y_val_pred = xgb_reg.predict(X_val)

# Calculate the evaluation metrics
mae = mean_absolute_error(y_val, y_val_pred)
mse = mean_squared_error(y_val, y_val_pred)
rmse = sqrt(mse)  # Calculate RMSE
spearman_corr_value = spearman_corr(y_val, y_val_pred)
kendall_corr_value = kendall_corr(y_val, y_val_pred)

# Print all evaluation metrics
print(f"Validation MAE: {mae:.4f}")
print(f"Validation MSE: {mse:.4f}")
print(f"Validation RMSE: {rmse:.4f}")
print(f"Validation Spearman's Rank Correlation Coefficient: {spearman_corr_value:.4f}")
print(f"Validation Kendall's Tau: {kendall_corr_value:.4f}")

# Create submission file
def create_submission_file(model, X_test, test_ids, output_file):
    predictions = model.predict(X_test)
    submission = pd.DataFrame(
        {
            "id": test_ids,
            "score": np.round(predictions, 8),
        }
    )
    submission.to_csv(output_file, index=False)

# Generate submission file
submission_file = "submission.csv"
create_submission_file(xgb_reg, X_test, test_data["id"], submission_file)
# Out:
# [0]	validation_0-rmse:0.81628	validation_1-rmse:0.81500
# [1]	validation_0-rmse:0.81549	validation_1-rmse:0.81436
# [2]	validation_0-rmse:0.81474	validation_1-rmse:0.81371
# [3]	validation_0-rmse:0.81398	validation_1-rmse:0.81306
# [4]	validation_0-rmse:0.81323	validation_1-rmse:0.81240
# [5]	validation_0-rmse:0.81245	validation_1-rmse:0.81170
# [6]	validation_0-rmse:0.81168	validation_1-rmse:0.81106
# [7]	validation_0-rmse:0.81096	validation_1-rmse:0.81045
# [8]	validation_0-rmse:0.81021	validation_1-rmse:0.80980
# [9]	validation_0-rmse:0.80945	validation_1-rmse:0.80924
# [10]	validation_0-rmse:0.80869	validation_1-rmse:0.80855
# [11]	validation_0-rmse:0.80796	validation_1-rmse:0.80795
# [12]	validation_0-rmse:0.80719	validation_1-rmse:0.80730
# [13]	validation_0-rmse:0.80643	validation_1-rmse:0.80667
# [14]	validation_0-rmse:0.80566	validation_1-rmse:0.80607
# D:\Program Files\anaconda 3\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:12:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "lambda_" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [15]	validation_0-rmse:0.80493	validation_1-rmse:0.80542
# [16]	validation_0-rmse:0.80418	validation_1-rmse:0.80476
# [17]	validation_0-rmse:0.80342	validation_1-rmse:0.80414
# [18]	validation_0-rmse:0.80266	validation_1-rmse:0.80355
# [19]	validation_0-rmse:0.80191	validation_1-rmse:0.80296
# [20]	validation_0-rmse:0.80118	validation_1-rmse:0.80236
# [21]	validation_0-rmse:0.80048	validation_1-rmse:0.80182
# [22]	validation_0-rmse:0.79978	validation_1-rmse:0.80125
# [23]	validation_0-rmse:0.79904	validation_1-rmse:0.80062
# [24]	validation_0-rmse:0.79831	validation_1-rmse:0.80006
# [25]	validation_0-rmse:0.79759	validation_1-rmse:0.79946
# [26]	validation_0-rmse:0.79686	validation_1-rmse:0.79889
# [27]	validation_0-rmse:0.79614	validation_1-rmse:0.79834
# [28]	validation_0-rmse:0.79538	validation_1-rmse:0.79774
# [29]	validation_0-rmse:0.79466	validation_1-rmse:0.79720
# [30]	validation_0-rmse:0.79397	validation_1-rmse:0.79663
# [31]	validation_0-rmse:0.79331	validation_1-rmse:0.79608
# [32]	validation_0-rmse:0.79261	validation_1-rmse:0.79548
# [33]	validation_0-rmse:0.79190	validation_1-rmse:0.79493
# [34]	validation_0-rmse:0.79122	validation_1-rmse:0.79440
# [35]	validation_0-rmse:0.79051	validation_1-rmse:0.79391
# [36]	validation_0-rmse:0.78982	validation_1-rmse:0.79337
# [37]	validation_0-rmse:0.78912	validation_1-rmse:0.79280
# [38]	validation_0-rmse:0.78842	validation_1-rmse:0.79221
# [39]	validation_0-rmse:0.78772	validation_1-rmse:0.79162
# [40]	validation_0-rmse:0.78703	validation_1-rmse:0.79105
# [41]	validation_0-rmse:0.78640	validation_1-rmse:0.79059
# [42]	validation_0-rmse:0.78576	validation_1-rmse:0.79008
# [43]	validation_0-rmse:0.78507	validation_1-rmse:0.78951
# [44]	validation_0-rmse:0.78441	validation_1-rmse:0.78895
# [45]	validation_0-rmse:0.78370	validation_1-rmse:0.78837
# [46]	validation_0-rmse:0.78305	validation_1-rmse:0.78782
# [47]	validation_0-rmse:0.78235	validation_1-rmse:0.78732
# [48]	validation_0-rmse:0.78166	validation_1-rmse:0.78680
# [49]	validation_0-rmse:0.78100	validation_1-rmse:0.78628
# [50]	validation_0-rmse:0.78032	validation_1-rmse:0.78577
# [51]	validation_0-rmse:0.77965	validation_1-rmse:0.78521
# [52]	validation_0-rmse:0.77895	validation_1-rmse:0.78465
# [53]	validation_0-rmse:0.77828	validation_1-rmse:0.78410
# [54]	validation_0-rmse:0.77763	validation_1-rmse:0.78355
# [55]	validation_0-rmse:0.77697	validation_1-rmse:0.78300
# [56]	validation_0-rmse:0.77630	validation_1-rmse:0.78246
# [57]	validation_0-rmse:0.77563	validation_1-rmse:0.78193
# [58]	validation_0-rmse:0.77498	validation_1-rmse:0.78140
# [59]	validation_0-rmse:0.77430	validation_1-rmse:0.78092
# [60]	validation_0-rmse:0.77363	validation_1-rmse:0.78042
# [61]	validation_0-rmse:0.77304	validation_1-rmse:0.77997
# [62]	validation_0-rmse:0.77241	validation_1-rmse:0.77956
# [63]	validation_0-rmse:0.77176	validation_1-rmse:0.77905
# [64]	validation_0-rmse:0.77111	validation_1-rmse:0.77854
# [65]	validation_0-rmse:0.77047	validation_1-rmse:0.77804
# [66]	validation_0-rmse:0.76986	validation_1-rmse:0.77761
# [67]	validation_0-rmse:0.76923	validation_1-rmse:0.77712
# [68]	validation_0-rmse:0.76858	validation_1-rmse:0.77663
# [69]	validation_0-rmse:0.76797	validation_1-rmse:0.77620
# [70]	validation_0-rmse:0.76737	validation_1-rmse:0.77575
# [71]	validation_0-rmse:0.76671	validation_1-rmse:0.77524
# [72]	validation_0-rmse:0.76609	validation_1-rmse:0.77475
# [73]	validation_0-rmse:0.76547	validation_1-rmse:0.77425
# [74]	validation_0-rmse:0.76486	validation_1-rmse:0.77377
# [75]	validation_0-rmse:0.76423	validation_1-rmse:0.77331
# [76]	validation_0-rmse:0.76361	validation_1-rmse:0.77288
# [77]	validation_0-rmse:0.76300	validation_1-rmse:0.77246
# [78]	validation_0-rmse:0.76239	validation_1-rmse:0.77194
# [79]	validation_0-rmse:0.76179	validation_1-rmse:0.77144
# [80]	validation_0-rmse:0.76118	validation_1-rmse:0.77094
# [81]	validation_0-rmse:0.76059	validation_1-rmse:0.77048
# [82]	validation_0-rmse:0.75999	validation_1-rmse:0.76998
# [83]	validation_0-rmse:0.75940	validation_1-rmse:0.76953
# [84]	validation_0-rmse:0.75880	validation_1-rmse:0.76907
# [85]	validation_0-rmse:0.75818	validation_1-rmse:0.76862
# [86]	validation_0-rmse:0.75756	validation_1-rmse:0.76810
# [87]	validation_0-rmse:0.75695	validation_1-rmse:0.76767
# [88]	validation_0-rmse:0.75634	validation_1-rmse:0.76723
# [89]	validation_0-rmse:0.75574	validation_1-rmse:0.76678
# [90]	validation_0-rmse:0.75515	validation_1-rmse:0.76631
# [91]	validation_0-rmse:0.75459	validation_1-rmse:0.76589
# [92]	validation_0-rmse:0.75400	validation_1-rmse:0.76546
# [93]	validation_0-rmse:0.75342	validation_1-rmse:0.76507
# [94]	validation_0-rmse:0.75285	validation_1-rmse:0.76468
# [95]	validation_0-rmse:0.75226	validation_1-rmse:0.76425
# [96]	validation_0-rmse:0.75170	validation_1-rmse:0.76383
# [97]	validation_0-rmse:0.75114	validation_1-rmse:0.76334
# [98]	validation_0-rmse:0.75055	validation_1-rmse:0.76292
# [99]	validation_0-rmse:0.74996	validation_1-rmse:0.76248
# [100]	validation_0-rmse:0.74939	validation_1-rmse:0.76205
# [101]	validation_0-rmse:0.74882	validation_1-rmse:0.76164
# [102]	validation_0-rmse:0.74824	validation_1-rmse:0.76117
# [103]	validation_0-rmse:0.74770	validation_1-rmse:0.76072
# [104]	validation_0-rmse:0.74712	validation_1-rmse:0.76022
# [105]	validation_0-rmse:0.74656	validation_1-rmse:0.75982
# [106]	validation_0-rmse:0.74600	validation_1-rmse:0.75936
# [107]	validation_0-rmse:0.74542	validation_1-rmse:0.75894
# [108]	validation_0-rmse:0.74485	validation_1-rmse:0.75860
# [109]	validation_0-rmse:0.74432	validation_1-rmse:0.75821
# [110]	validation_0-rmse:0.74379	validation_1-rmse:0.75781
# [111]	validation_0-rmse:0.74326	validation_1-rmse:0.75739
# [112]	validation_0-rmse:0.74271	validation_1-rmse:0.75701
# [113]	validation_0-rmse:0.74214	validation_1-rmse:0.75660
# [114]	validation_0-rmse:0.74159	validation_1-rmse:0.75620
# [115]	validation_0-rmse:0.74104	validation_1-rmse:0.75573
# [116]	validation_0-rmse:0.74049	validation_1-rmse:0.75535
# [117]	validation_0-rmse:0.73995	validation_1-rmse:0.75500
# [118]	validation_0-rmse:0.73940	validation_1-rmse:0.75457
# [119]	validation_0-rmse:0.73885	validation_1-rmse:0.75413
# [120]	validation_0-rmse:0.73833	validation_1-rmse:0.75374
# [121]	validation_0-rmse:0.73785	validation_1-rmse:0.75336
# [122]	validation_0-rmse:0.73732	validation_1-rmse:0.75296
# [123]	validation_0-rmse:0.73680	validation_1-rmse:0.75254
# [124]	validation_0-rmse:0.73626	validation_1-rmse:0.75216
# [125]	validation_0-rmse:0.73573	validation_1-rmse:0.75182
# [126]	validation_0-rmse:0.73522	validation_1-rmse:0.75144
# [127]	validation_0-rmse:0.73469	validation_1-rmse:0.75102
# [128]	validation_0-rmse:0.73416	validation_1-rmse:0.75064
# [129]	validation_0-rmse:0.73365	validation_1-rmse:0.75023
# [130]	validation_0-rmse:0.73314	validation_1-rmse:0.74988
# [131]	validation_0-rmse:0.73264	validation_1-rmse:0.74956
# [132]	validation_0-rmse:0.73209	validation_1-rmse:0.74916
# [133]	validation_0-rmse:0.73160	validation_1-rmse:0.74877
# [134]	validation_0-rmse:0.73108	validation_1-rmse:0.74836
# [135]	validation_0-rmse:0.73059	validation_1-rmse:0.74799
# [136]	validation_0-rmse:0.73010	validation_1-rmse:0.74761
# [137]	validation_0-rmse:0.72962	validation_1-rmse:0.74728
# [138]	validation_0-rmse:0.72912	validation_1-rmse:0.74689
# [139]	validation_0-rmse:0.72862	validation_1-rmse:0.74657
# [140]	validation_0-rmse:0.72809	validation_1-rmse:0.74622
# [141]	validation_0-rmse:0.72758	validation_1-rmse:0.74585
# [142]	validation_0-rmse:0.72709	validation_1-rmse:0.74548
# [143]	validation_0-rmse:0.72661	validation_1-rmse:0.74506
# [144]	validation_0-rmse:0.72610	validation_1-rmse:0.74467
# [145]	validation_0-rmse:0.72558	validation_1-rmse:0.74428
# [146]	validation_0-rmse:0.72512	validation_1-rmse:0.74394
# [147]	validation_0-rmse:0.72461	validation_1-rmse:0.74359
# [148]	validation_0-rmse:0.72416	validation_1-rmse:0.74322
# [149]	validation_0-rmse:0.72371	validation_1-rmse:0.74287
# [150]	validation_0-rmse:0.72325	validation_1-rmse:0.74252
# [151]	validation_0-rmse:0.72278	validation_1-rmse:0.74214
# [152]	validation_0-rmse:0.72231	validation_1-rmse:0.74180
# [153]	validation_0-rmse:0.72184	validation_1-rmse:0.74146
# [154]	validation_0-rmse:0.72137	validation_1-rmse:0.74116
# [155]	validation_0-rmse:0.72087	validation_1-rmse:0.74077
# [156]	validation_0-rmse:0.72038	validation_1-rmse:0.74042
# [157]	validation_0-rmse:0.71994	validation_1-rmse:0.74010
# [158]	validation_0-rmse:0.71946	validation_1-rmse:0.73974
# [159]	validation_0-rmse:0.71899	validation_1-rmse:0.73942
# [160]	validation_0-rmse:0.71852	validation_1-rmse:0.73906
# [161]	validation_0-rmse:0.71806	validation_1-rmse:0.73875
# [162]	validation_0-rmse:0.71761	validation_1-rmse:0.73839
# [163]	validation_0-rmse:0.71712	validation_1-rmse:0.73807
# [164]	validation_0-rmse:0.71665	validation_1-rmse:0.73772
# [165]	validation_0-rmse:0.71620	validation_1-rmse:0.73737
# [166]	validation_0-rmse:0.71575	validation_1-rmse:0.73701
# [167]	validation_0-rmse:0.71526	validation_1-rmse:0.73666
# [168]	validation_0-rmse:0.71483	validation_1-rmse:0.73637
# [169]	validation_0-rmse:0.71436	validation_1-rmse:0.73606
# [170]	validation_0-rmse:0.71392	validation_1-rmse:0.73576
# [171]	validation_0-rmse:0.71349	validation_1-rmse:0.73549
# [172]	validation_0-rmse:0.71302	validation_1-rmse:0.73520
# [173]	validation_0-rmse:0.71256	validation_1-rmse:0.73490
# [174]	validation_0-rmse:0.71212	validation_1-rmse:0.73457
# [175]	validation_0-rmse:0.71168	validation_1-rmse:0.73425
# [176]	validation_0-rmse:0.71124	validation_1-rmse:0.73400
# [177]	validation_0-rmse:0.71080	validation_1-rmse:0.73368
# [178]	validation_0-rmse:0.71036	validation_1-rmse:0.73339
# [179]	validation_0-rmse:0.70989	validation_1-rmse:0.73311
# [180]	validation_0-rmse:0.70944	validation_1-rmse:0.73282
# [181]	validation_0-rmse:0.70898	validation_1-rmse:0.73254
# [182]	validation_0-rmse:0.70853	validation_1-rmse:0.73226
# [183]	validation_0-rmse:0.70809	validation_1-rmse:0.73194
# [184]	validation_0-rmse:0.70767	validation_1-rmse:0.73166
# [185]	validation_0-rmse:0.70721	validation_1-rmse:0.73140
# [186]	validation_0-rmse:0.70679	validation_1-rmse:0.73115
# [187]	validation_0-rmse:0.70636	validation_1-rmse:0.73085
# [188]	validation_0-rmse:0.70591	validation_1-rmse:0.73051
# [189]	validation_0-rmse:0.70547	validation_1-rmse:0.73021
# [190]	validation_0-rmse:0.70503	validation_1-rmse:0.72986
# [191]	validation_0-rmse:0.70460	validation_1-rmse:0.72956
# [192]	validation_0-rmse:0.70421	validation_1-rmse:0.72928
# [193]	validation_0-rmse:0.70376	validation_1-rmse:0.72900
# [194]	validation_0-rmse:0.70332	validation_1-rmse:0.72870
# [195]	validation_0-rmse:0.70293	validation_1-rmse:0.72843
# [196]	validation_0-rmse:0.70249	validation_1-rmse:0.72818
# [197]	validation_0-rmse:0.70207	validation_1-rmse:0.72789
# [198]	validation_0-rmse:0.70163	validation_1-rmse:0.72757
# [199]	validation_0-rmse:0.70122	validation_1-rmse:0.72732
# [200]	validation_0-rmse:0.70080	validation_1-rmse:0.72708
# [201]	validation_0-rmse:0.70037	validation_1-rmse:0.72680
# [202]	validation_0-rmse:0.69994	validation_1-rmse:0.72657
# [203]	validation_0-rmse:0.69955	validation_1-rmse:0.72630
# [204]	validation_0-rmse:0.69912	validation_1-rmse:0.72598
# [205]	validation_0-rmse:0.69870	validation_1-rmse:0.72567
# [206]	validation_0-rmse:0.69833	validation_1-rmse:0.72541
# [207]	validation_0-rmse:0.69791	validation_1-rmse:0.72518
# [208]	validation_0-rmse:0.69753	validation_1-rmse:0.72493
# [209]	validation_0-rmse:0.69713	validation_1-rmse:0.72468
# [210]	validation_0-rmse:0.69672	validation_1-rmse:0.72441
# [211]	validation_0-rmse:0.69630	validation_1-rmse:0.72417
# [212]	validation_0-rmse:0.69591	validation_1-rmse:0.72394
# [213]	validation_0-rmse:0.69549	validation_1-rmse:0.72367
# [214]	validation_0-rmse:0.69509	validation_1-rmse:0.72346
# [215]	validation_0-rmse:0.69469	validation_1-rmse:0.72318
# [216]	validation_0-rmse:0.69428	validation_1-rmse:0.72291
# [217]	validation_0-rmse:0.69389	validation_1-rmse:0.72270
# [218]	validation_0-rmse:0.69348	validation_1-rmse:0.72241
# [219]	validation_0-rmse:0.69309	validation_1-rmse:0.72212
# [220]	validation_0-rmse:0.69271	validation_1-rmse:0.72189
# [221]	validation_0-rmse:0.69231	validation_1-rmse:0.72162
# [222]	validation_0-rmse:0.69192	validation_1-rmse:0.72140
# [223]	validation_0-rmse:0.69153	validation_1-rmse:0.72118
# [224]	validation_0-rmse:0.69115	validation_1-rmse:0.72094
# [225]	validation_0-rmse:0.69076	validation_1-rmse:0.72068
# [226]	validation_0-rmse:0.69037	validation_1-rmse:0.72048
# [227]	validation_0-rmse:0.68995	validation_1-rmse:0.72020
# [228]	validation_0-rmse:0.68955	validation_1-rmse:0.71991
# [229]	validation_0-rmse:0.68915	validation_1-rmse:0.71962
# [230]	validation_0-rmse:0.68875	validation_1-rmse:0.71936
# [231]	validation_0-rmse:0.68836	validation_1-rmse:0.71907
# [232]	validation_0-rmse:0.68799	validation_1-rmse:0.71887
# [233]	validation_0-rmse:0.68760	validation_1-rmse:0.71868
# [234]	validation_0-rmse:0.68722	validation_1-rmse:0.71839
# [235]	validation_0-rmse:0.68688	validation_1-rmse:0.71814
# [236]	validation_0-rmse:0.68654	validation_1-rmse:0.71791
# [237]	validation_0-rmse:0.68615	validation_1-rmse:0.71769
# [238]	validation_0-rmse:0.68576	validation_1-rmse:0.71751
# [239]	validation_0-rmse:0.68537	validation_1-rmse:0.71727
# [240]	validation_0-rmse:0.68499	validation_1-rmse:0.71710
# [241]	validation_0-rmse:0.68464	validation_1-rmse:0.71684
# [242]	validation_0-rmse:0.68431	validation_1-rmse:0.71659
# [243]	validation_0-rmse:0.68396	validation_1-rmse:0.71639
# [244]	validation_0-rmse:0.68359	validation_1-rmse:0.71610
# [245]	validation_0-rmse:0.68324	validation_1-rmse:0.71586
# [246]	validation_0-rmse:0.68290	validation_1-rmse:0.71568
# [247]	validation_0-rmse:0.68257	validation_1-rmse:0.71548
# [248]	validation_0-rmse:0.68220	validation_1-rmse:0.71523
# [249]	validation_0-rmse:0.68184	validation_1-rmse:0.71499
# [250]	validation_0-rmse:0.68152	validation_1-rmse:0.71480
# [251]	validation_0-rmse:0.68114	validation_1-rmse:0.71456
# [252]	validation_0-rmse:0.68076	validation_1-rmse:0.71435
# [253]	validation_0-rmse:0.68041	validation_1-rmse:0.71411
# [254]	validation_0-rmse:0.68007	validation_1-rmse:0.71387
# [255]	validation_0-rmse:0.67972	validation_1-rmse:0.71367
# [256]	validation_0-rmse:0.67937	validation_1-rmse:0.71347
# [257]	validation_0-rmse:0.67901	validation_1-rmse:0.71327
# [258]	validation_0-rmse:0.67864	validation_1-rmse:0.71308
# [259]	validation_0-rmse:0.67831	validation_1-rmse:0.71292
# [260]	validation_0-rmse:0.67796	validation_1-rmse:0.71269
# [261]	validation_0-rmse:0.67758	validation_1-rmse:0.71246
# [262]	validation_0-rmse:0.67722	validation_1-rmse:0.71225
# [263]	validation_0-rmse:0.67689	validation_1-rmse:0.71208
# [264]	validation_0-rmse:0.67655	validation_1-rmse:0.71182
# [265]	validation_0-rmse:0.67623	validation_1-rmse:0.71164
# [266]	validation_0-rmse:0.67586	validation_1-rmse:0.71141
# [267]	validation_0-rmse:0.67550	validation_1-rmse:0.71116
# [268]	validation_0-rmse:0.67515	validation_1-rmse:0.71092
# [269]	validation_0-rmse:0.67478	validation_1-rmse:0.71069
# [270]	validation_0-rmse:0.67445	validation_1-rmse:0.71048
# [271]	validation_0-rmse:0.67409	validation_1-rmse:0.71026
# [272]	validation_0-rmse:0.67373	validation_1-rmse:0.71004
# [273]	validation_0-rmse:0.67337	validation_1-rmse:0.70985
# [274]	validation_0-rmse:0.67302	validation_1-rmse:0.70963
# [275]	validation_0-rmse:0.67267	validation_1-rmse:0.70945
# [276]	validation_0-rmse:0.67233	validation_1-rmse:0.70925
# [277]	validation_0-rmse:0.67198	validation_1-rmse:0.70905
# [278]	validation_0-rmse:0.67164	validation_1-rmse:0.70886
# [279]	validation_0-rmse:0.67129	validation_1-rmse:0.70866
# [280]	validation_0-rmse:0.67095	validation_1-rmse:0.70850
# [281]	validation_0-rmse:0.67062	validation_1-rmse:0.70829
# [282]	validation_0-rmse:0.67030	validation_1-rmse:0.70808
# [283]	validation_0-rmse:0.66997	validation_1-rmse:0.70785
# [284]	validation_0-rmse:0.66967	validation_1-rmse:0.70769
# [285]	validation_0-rmse:0.66933	validation_1-rmse:0.70745
# [286]	validation_0-rmse:0.66903	validation_1-rmse:0.70726
# [287]	validation_0-rmse:0.66869	validation_1-rmse:0.70707
# [288]	validation_0-rmse:0.66835	validation_1-rmse:0.70685
# [289]	validation_0-rmse:0.66801	validation_1-rmse:0.70665
# [290]	validation_0-rmse:0.66770	validation_1-rmse:0.70642
# [291]	validation_0-rmse:0.66736	validation_1-rmse:0.70624
# [292]	validation_0-rmse:0.66703	validation_1-rmse:0.70604
# [293]	validation_0-rmse:0.66672	validation_1-rmse:0.70584
# [294]	validation_0-rmse:0.66639	validation_1-rmse:0.70566
# [295]	validation_0-rmse:0.66609	validation_1-rmse:0.70549
# [296]	validation_0-rmse:0.66575	validation_1-rmse:0.70532
# [297]	validation_0-rmse:0.66542	validation_1-rmse:0.70513
# [298]	validation_0-rmse:0.66512	validation_1-rmse:0.70498
# [299]	validation_0-rmse:0.66481	validation_1-rmse:0.70477
# Validation MAE: 0.6034
# Validation MSE: 0.4967
# Validation RMSE: 0.7048
# Validation Spearman's Rank Correlation Coefficient: 0.5818
# Validation Kendall's Tau: 0.4059

# %%
# # Parameter grid for random search
# param_grid = {
#     "learning_rate": [0.01, 0.03],
#     "max_depth": [7, 10],
#     "n_estimators": [500],
#     "subsample": [0.7, 1.0],
#     "colsample_bytree": [0.8],
#     "gamma": [0.3, 0.5, 1],
#     "lambda": [0.5, 0.8, 1],
#     "alpha": [1, 2, 5, 10],
# }
